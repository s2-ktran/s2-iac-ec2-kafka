# %% [markdown]
# # HybridV Demo

# %% [markdown]
# ### Database Configuration

# %%
# %%sql
# CREATE DATABASE fleet_mgmt;
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# USE fleet_mgmt;
# Out:
# ++
# ||
# ++
# ++

# %% [markdown]
# ### DynamoDB + Kafka Integration

# %%
# %%sql
# CREATE TABLE event_log (
#     event_id VARCHAR(50),
#     timestamp DATETIME,
#     type VARCHAR(50),
#     description VARCHAR(50),
#     related_vehicle_id VARCHAR(50),
#     additional_info JSON
# );
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# -- Create pipelines for Kafka
# CREATE OR REPLACE PIPELINE event_logs_kafka AS
# LOAD DATA KAFKA '34.228.198.249/event_topic'
# INTO TABLE event_log
# (
#     event_id <- event_id,
#     timestamp <- timestamp,
#     type <- type,
#     description <- description,
#     related_vehicle_id <- related_vehicle_id,
#     additional_info <- additional_info
# )
# FORMAT JSON;
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# SHOW PIPELINES;
# Out:
# +-------------------------+---------+-----------+
# | Pipelines_in_fleet_mgmt |  State  | Scheduled |
# +-------------------------+---------+-----------+
# |   migration.ride_data   | Running |   False   |
# |   migration.user_data   | Running |   False   |
# |     event_logs_kafka    | Stopped |   False   |
# |    vehicle_data_kafka   | Stopped |   False   |
# +-------------------------+---------+-----------+

# %%
# %%sql
# START PIPELINE event_logs_kafka;
# Out:
# ++
# ||
# ++
# ++

# %%
# %%sql
# SELECT COUNT(*) FROM event_logs;
# Out:
# +--------------+---------------------+-------------+-------------------------+--------------------+--------------------------------------+
# |   event_id   |      timestamp      |     type    |       description       | related_vehicle_id |           additional_info            |
# +--------------+---------------------+-------------+-------------------------+--------------------+--------------------------------------+
# | event_761889 | 2024-07-09 10:47:24 |   accident  | Unscheduled maintenance |     vehicle_63     | {'info': 'Additional event details'} |
# | event_27539  | 2024-07-09 10:47:24 |   accident  | Unscheduled maintenance |     vehicle_4      | {'info': 'Additional event details'} |
# | event_563127 | 2024-07-09 10:47:24 | maintenance |  Scheduled maintenance  |     vehicle_68     | {'info': 'Additional event details'} |
# | event_466504 | 2024-07-09 10:47:24 |   accident  |      Minor accident     |     vehicle_13     | {'info': 'Additional event details'} |
# ...

# %% [markdown]
# ### Cleanup

# %%
# %%sql
# DROP DATABASE fleet_mgmt;
# Out:
# ++
# ||
# ++
# ++
